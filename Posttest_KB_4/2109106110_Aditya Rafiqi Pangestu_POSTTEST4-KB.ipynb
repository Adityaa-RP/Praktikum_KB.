# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Membaca data dari file CSV ke dalam DataFrame

# %%
df = pd.read_csv("data.csv")

# %% [markdown]
# # Membagi dataset menjadi training set dan testing set dengan proporsi 70:30

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns='diagnosis') # feature
y = df['diagnosis'] # target

# Membagi dataset menjadi training set (70%) dan testing set (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Output untuk memeriksa ukuran training dan testing set
print("Ukuran Training Set:", X_train.shape)
print("Ukuran Testing Set:", X_test.shape)
# Out:
# Ukuran Training Set: (398, 33)
# Ukuran Testing Set: (171, 33)

# %% [markdown]
# # Copy Dataset

# %%
df_copy = df.copy()

# %% [markdown]
# # Melakukan normalisasi data pada salah satu attribute menggunakan Min Max scaler

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst  data_worst  Unnamed: 33
# 0    842302         M        17.99         10.38          122.80     1001.0          0.11840           0.27760          0.3001              0.14710         0.2419                 0.07871     1.0950      0.9053         8.589   153.40       0.006399         0.04904       0.05373            0.01587      0.03003              0.006193         25.38          17.33           184.60      2019.0            0.1622             0.6656           0.7119                0.2654          0.4601                  0.11890         NaN          NaN
# 1    842517         M        20.57         17.77          132.90     1326.0          0.08474           0.07864          0.0869              0.07017         0.1812                 0.05667     0.5435      0.7339         3.398    74.08       0.005225         0.01308       0.01860            0.01340      0.01389              0.003532         24.99          23.41           158.80      1956.0            0.1238             0.1866           0.2416                0.1860          0.2750                  0.08902         NaN          NaN
# 2  84300903         M        19.69         21.25          130.00     1203.0          0.10960           0.15990          0.1974              0.12790         0.2069                 0.05999     0.7456      0.7869         4.585    94.03       0.006150         0.04006       0.03832            0.02058      0.02250              0.004571         23.57          25.53           152.50      1709.0            0.1444             0.4245           0.4504                0.2430          0.3613                  0.08758         NaN          NaN
# 3  84348301         M        11.42         20.38           77.58      386.1          0.14250           0.28390          0.2414              0.10520         0.2597                 0.09744     0.4956      1.1560         3.445    27.23       0.009110         0.07458       0.05661            0.01867      0.05963              0.009208         14.91          26.50            98.87       567.7            0.2098             0.8663           0.6869                0.2575          0.6638                  0.17300         NaN          NaN
# 4  84358402         M        20.29         14.34          135.10     1297.0          0.10030           0.13280          0.1980              0.10430         0.1809                 0.05883     0.7572      0.7813         5.438    94.44       0.011490         0.02461       0.05688            0.01885      0.01756              0.005115         22.54          16.67           152.20      1575.0            0.1374             0.2050           0.4000                0.1625          0.2364                  0.07678         NaN          NaN

# %%
from sklearn.preprocessing import MinMaxScaler

# Atribut yang di normalisasi
atribut_normalisasi = 'radius_mean'

#Membuat objek MinMaxScaler
mm = MinMaxScaler()

# Melakukan normalisasi Min-Max pada atribut 'radius_mean'
df_copy[atribut_normalisasi] = mm.fit_transform(df_copy[[atribut_normalisasi]])

# Mencetak nilai
print('Nilai Min : ',df_copy[atribut_normalisasi].min())
print('Nilai Max : ',df_copy[atribut_normalisasi].max())
print('seluruh Nilai atribut : ')
print(df_copy[atribut_normalisasi])
# Out:
# Nilai Min :  0.0
# Nilai Max :  1.0
# seluruh Nilai atribut :
# 0      0.521037
# 1      0.643144
# 2      0.601496
# 3      0.210090
# 4      0.629893
#          ...
# 564    0.690000
# 565    0.622320
# 566    0.455251
# 567    0.644564
# 568    0.036869
# Name: radius_mean, Length: 569, dtype: float64

# %% [markdown]
# # Melakukan  standarisasi pada dataset

# %%
from sklearn.preprocessing import StandardScaler

# Membuat objek StandardScaler
ss = StandardScaler()

# Mengidentifikasi kolom-kolom numerik
numeric_columns = df_copy.select_dtypes(include=['float64', 'int64']).columns

# Melakukan standarisasi pada kolom-kolom numerik
df_copy[numeric_columns] = ss.fit_transform(df_copy[numeric_columns])

print('Hasil Standarisasi :')
df_copy[numeric_columns]
# Out:
# Hasil Standarisasi :
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\extmath.py:1050: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\extmath.py:1055: RuntimeWarning: invalid value encountered in true_divide
#   T = new_sum / new_sample_count
# c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\extmath.py:1075: RuntimeWarning: invalid value encountered in true_divide
#   new_unnormalized_variance -= correction**2 / new_sample_count
#            id  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se   area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_wor
NaN
#
# [569 rows x 33 columns]

# %% [markdown]
# # Melakukan Data cleaning pada data dengan nilai null

# %% [markdown]
# **Sebelum**

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# symmetry_worst               0
# fractal_dimension_worst      0
# data_worst                 569
# Unnamed: 33                569
# dtype: int64

# %% [markdown]
# # Dikarenakan data null diatas tidak dapat dipanggil jadi  saya buat data null baru

# %%
# Membuat dataset contoh tanpa nilai null
data = {
    'Kolom1': [1, 2, 3, 4, 5],
    'Kolom2': ['A', 'B', 'C', 'D', 'E']
}

df = pd.DataFrame(data)

# Menambahkan kolom baru dengan nilai null
df['Kolom3'] = None

# Sekarang, df memiliki kolom baru (Kolom3) dengan nilai null di setiap baris
print(df)
# Out:
#    Kolom1 Kolom2 Kolom3
# 0       1      A   None
# 1       2      B   None
# 2       3      C   None
# 3       4      D   None
# 4       5      E   None

# %% [markdown]
# # Terdapat 5 nilai null pada atribut Kolom3

# %% [markdown]
# **Sesudah**

# %%
# df.data_Unnamed = df.data.Unnamed(df.data.Unnamed.mean(),inplace=True)

# %%
from sklearn.impute import SimpleImputer

# Mengganti nilai menjadi modus
imputer = SimpleImputer(strategy='most_frequent')

# Mengisi nilai yang hilang dalam kolom 'Unnamed: 32'
df["Kolom3"] = imputer.fit_transform(df[["Kolom3"]])

# Mencetak jumlah nilai null setelah penggunaan SimpleImputer
print("Jumlah null setelah menggunakan SimpleImputer: ")
print(df.isna().sum())
# Out:
# Jumlah null setelah menggunakan SimpleImputer:
# Kolom1    0
# Kolom2    0
# Kolom3    5
# dtype: int64

# %% [markdown]
# # Melakukan Data cleaning pada data dengan nilai duplikat

# %% [markdown]
# **Sebelum**

# %%
print("Jumlah nilai Duplikat:", df.duplicated().sum())
# Out:
# Jumlah nilai Duplikat: 0

# %% [markdown]
# **Sesudah**

# %%
# Menghapus baris-baris yang memiliki nilai duplikat
df.drop_duplicates(inplace=True)

print("Setelah menggunakan fungsi drop_duplicates()")
print("Jumlah nilai Duplikat:", df.duplicated().sum())
# Out:
# Setelah menggunakan fungsi drop_duplicates()
# Jumlah nilai Duplikat: 0

# %% [markdown]
# # Mengganti tipe data salah satu attribute angka

# %% [markdown]
# **Sebelum**

# %%
df.head()
# Out:
#    Kolom1 Kolom2 Kolom3
# 0       1      A   None
# 1       2      B   None
# 2       3      C   None
# 3       4      D   None
# 4       5      E   None

# %% [markdown]
# Atribut id masih bernilai Integer

# %% [markdown]
# **Sesudah**

# %%
# Mengubah tipe data atribut score menjadi float
df['Kolom1'] = df['Kolom1'].astype(float)
df.head()
# Out:
#    Kolom1 Kolom2 Kolom3
# 0     1.0      A   None
# 1     2.0      B   None
# 2     3.0      C   None
# 3     4.0      D   None
# 4     5.0      E   None

# %% [markdown]
# # Record atribut id sudah berubah menjadi float

# %%
from sklearn.preprocessing import OneHotEncoder

# Melakukan one-hot encoding pada kolom 'platform	'
data_encoded = pd.get_dummies(df, columns=['Kolom1'], dtype=bool)

# Mengatur opsi tampilan untuk menampilkan seluruh kolom
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)

# Menampilkan dataset yang telah dienkoding
data_encoded
# Out:
#   Kolom2 Kolom3  Kolom1_1.0  Kolom1_2.0  Kolom1_3.0  Kolom1_4.0  Kolom1_5.0
# 0      A   None        True       False       False       False       False
# 1      B   None       False        True       False       False       False
# 2      C   None       False       False        True       False       False
# 3      D   None       False       False       False        True       False
# 4      E   None       False       False       False       False        True
